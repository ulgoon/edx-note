# %% [markdown]
# # Data Journalism Fundamental 2.0
# ![](https://mooc.jmsc.hku.hk/pluginfile.php/26379/course/section/10/slidelogos%20%281%29.png)
#
# ## Introduction for Session 1
# - Instructor: Simon Rogers
# - Videos: https://mooc.jmsc.hku.hk/mod/page/view.php?id=146
# - more informations: https://mooc.jmsc.hku.hk/mod/page/view.php?id=150

# %% [markdown]
# ### Assignment 1 (필수: 15점, 각 아이디어에 대해 5점씩)
# 한 뉴스 웹사이트에 방문해서 오늘부터 국제 또는 지역의 세가지 주요 뉴스 기사를 찾으세요. 그 기사들을 이용해서 기본적 데이터 저널리즘 기사를 위한 간단한 아이디어를 만들어보세요.
#
# Unemployment hits 10-year low as jobs report shows rebound for US economy
# https://www.theguardian.com/business/2017/may/05/april-jobs-report-us-economic-news
# Idea: 경제 이벤트와 월간 실업율 변화의 상관관계 시각화
#
# 1100만명…‘투표혁명’ 시작됐다
# http://www.hani.co.kr/arti/politics/politics_general/793595.html
# Idea: 지역별 사전투표율 시각화를 통해 각 지역의 시간별 투표율 변화를 보여줌
#
# 전국 미세먼지 주의보 발령…“부득이 외출 땐 마스크·긴소매”
# http://www.hani.co.kr/arti/society/environment/793613.html?_fr=mt2
# Idea: 미세먼지 농도의 변화량을 시각화를 통해 보여줌
#
# ### Assignment 2 (셋 중 하나를 선택하세요: 5%)
# a. 현재 거주하고 있는 국가 또는 지역의 데이터 저널리즘 리더가 누구인지 찾아보세요.
#
#
# b. 2017년 이전의 역사적인 데이터 저널리즘 기사를 찾아보세요.
#
# 메르스 확진환자 이동경로
# http://newstapa.org/26218
#
# 메르스 확진환자의 이동경로를 구글 맵 api를 활용하여 지도로 시각화 함으로써 메르스의 이동경로와 전염경로에 대해 이해할 수 있도록 도와준 매우 중요한 자료입니다. 외국에서 유행하던 메르스가 한국에 처음으로 유입된 뒤로 대한민국에 어떤 경로로 질병이 전염되는지를 눈으로 확인할 수 있어 흥미로웠으며, 질병통제에서 정부와 병원, 시민이 어떻게 행동해야 하는지를 알려줄 수 있는 매우 의미있는 자료입니다. 도표와 숫자로만 표현되는 관련 자료들을 지리정보에 접목하여 보여줌으로써 직관적인 정보전달이 가능하다는 점에서 오늘날 데이터 저널리즘이 어떻게 수행되어야 하는지를 대표적으로 보여줍니다.
#
# c. 자신의 가족 생활에 기반한 데이터 저널리즘 아이디어를 만들어보세요.
#
#
#
# ### Optional Final Project: Enterprise Data Story
#
# 여러분들은  MOOC에서 엔터프라이즈 데이터 스토리를 수행할 수 있는 기회를 얻게됩니다. 이 부분은 완전히 선택 사항이며 여러분들이 인증서를 취득하는 데에는 어떤 영향도 미치지 않습니다. 그렇기에 한번 배우는 것을 시도해보길 적극 추천합니다.
#
# 이 프로젝트는 어떻게 이루어지나요?
#
# - 개별적으로 혹은 그룹으로 프로젝트를 진행할 수 있습니다.
#
# - 그룹으로 선택하고자 하는 경우 1 주차까지 그룹을 구성하는 것이 좋겠습니다. 비슷한 아이디어를 가지고있는 다른 참가자들을 찾아내어 함께 이야기를 검토해보는 게 좋습니다.
#
# - 매주, 프로젝트에 대한 더 많은 가이드라인들이 주간 지침을 통해 전달될 것이며 이 게시물에도 업데이트될 것입니다. 이야기에 대한 참가자 여러분들의 진전을 위해 포럼이 매주 열릴 것입니다.
#
# - 그룹으로 제출하는 경우 한 번만 제출하고, 그룹 회원의 전체 이름으로 게시물 포스팅을 시작하세요.
#
# - 매주 말까지 매주 진도의 결과물을 제출하는 것을 권장하나, 나중에 제출해도 상관은 없습니다.
#
# - 여러분들의 이야기를 함께 토론하기 위해 한 두명의 강사 선생님들과의 온라인상의 미팅이 계획중에 있습니다.  3주 차에 보다 자세한 사항에 대해서 말씀드리겠습니다. 그러나 매주 마감일을 지킨 참가자들만이 온라인상으로 강사 선생님들을 만나 토론할 수 있는 기회를 얻을 수 있습니다.
#
# - 프로젝트 마감일은 코스가 끝난 후 1 주일 후인 6 월 11 일입니다.
# - 마감일 전에 최종 확정 된 이야기는 전문가들에 의해서 검토될 것이고, 뛰어난 프로젝트들은 따로 선별되어

# %% [markdown]
# ### Part1: Introduction
#
# #### What is data journalism?
# 1) Data journalism is about using numbers to tell the best story possible
# 2) You're no longer thinking solely about words
# 3) New and better tools all the time
#
# #### Popublica guide
# 1) Accessibility
# 2) Openness
#
# ### Part2: History
# - Notebook, Cassette Player for backup -typewriter-> printed on paper
#
# #### The Wall Street Journal
# Customer's Afternoon Letter
# #### John Snow
# mapped the cases -> great data visualization
# #### Investigation of the Detroit riots
# - Is data journalism? Is it journalism to publish a raw database?
#     - Who cares?
#     - I hope my competitors waste their time arguing about this as long as possible.
#
# #### Why has this happened?
# Role is about bringing that data and those numbers to life.
# - Tools
#     - Excel, Google spreadsheet
# - Open Data
#     - Data journalism is a way to open up that data and bring it back to the people who are afterall, paying for it to be collected
# - Trust
#     - Providing raw and open data with your stories essentially being transparent in what you do encourages trust because you literally have nothing to hide
# - Tools again
#     - visualizations
#
# ### Part3: The Data Leaders
# #### How do the world's data journalism leaders do this?
# - Just the Facts
#     - Propublica's Great Firewall of China shows real-time data on websites that are blocked in China
#     - Reuters
#     - South China Morning Post
# - Data-based news stories
#     - Often bring stories that are in the public eye to life, by revealing the numbers behind the news. Every story will have some data that goes with it.
#     - Caixin's story on China's property market
#     - The Strait's Times's General Election visualisation
#     - Indonesia's independent election data project, Kawal Pemilu
#     - The Guardian's Datablog
# - Local data telling stories
#     - Provides a great way for local news organizations with small resources to tell stories that work for their communities.
#     - Data is being published by governments.
#
# - Analysis and background
#     - to be analytical as well as to expose great exclusives
# - Deep-dive investications
#     - Data lends weight to deep investications which in turn can create complex news stories
#
# #### Show how it is such a flexible field.
# - most rewarding field of journalism around today.
# - allows you to experiment as a reporter
# - producing work that is both complicated rewarding and highlights the latest techniques in data journalism
# - becoming more and more specialized in their field, branching into coding and dataviz as much as writing and spreadsheets

# %% [markdown]
# ### Part4a: Latest Trends 1: Mobile
# - over 65% of the US market
# - many developers either don't have the inclination or the capacity to test their interactives and apps on every device out there
# - Smartphones provide us with a range of new ways of interacting with data visualizations
#     - swipe gestures
#     - gyroscope
#     - 360 sweeps
#     - geolocations
#     - vibration
# - Primarily develop for smartphones and have a rendition for desktop
# - strip out essentially all the interesting stuff: charts, interactives and iframes often vanish in mobile versions that are the same across an entire news site, with few concessions for mobile
#
# #### Will readers take on a 1000-word data analysis on a mobile?
# - For bigger operations, the challenge is how to combine that instant, platform-friendly approach with the beauty and elegance of the desktop visual output, whether or not you have the resources of the bigger news outlets
#
# ### Part4b: Latest Trends 2: Open Journalism
# - One-way process: relationship was almost entirely one-directional and couldn't be imagined any other way.
# - How else could you possibly interact with the journalist who had written the story?
#
# #### How statistics used to work
# - published in books written by statisticians
#
# >> Journalism today is at least as much about working with the community as it is telling the world what you think happened.
#
# - The ethos of open journalism is that reporting becomes better by gathering the expertise of the world and helping to curate it
#
# - Governments everywhere have thrown open their vaults and released it to the world.
#
# - Data journalism started to bring those two fields together, combining the flood of open data with a new type of reporting.
#     - not just about analyzing the data, making it available and showing you work.
#
# - News organizations make their work and raw data available for you to download and explore yourself as a matter of routine.
#
# >> As we all know, there's a lot of data out there and, as anyone who works with it knows, most of it is crap. The projects I'm most proud of have taken large, ugly datasets and refined them into something worth knowing - Alex Howard
#
# >> Storytelling informed by the numbers that have becomes as common as oxygen around us - Simon Rogers
#
# - The reader interface of those stories can be anything from data visualizations to indepth investigations and explainers.
# - Defining feature is that combination of storytelling with the actual, transparent data.
#
# >> News organizations may be campaigners for open information but by withholding that data, become complicit in a system which essentially keeps data private until it's no longer commercially valuable. It's all very well calling for governments to throw open the doors of their data vaults, but if you are not willing to be open too, what is that worth
#
# ### Part5: Workflow and MOOC Overview
# #### Typical workflow for a data journalist
# ![](https://mooc.jmsc.hku.hk/pluginfile.php/26403/mod_page/content/16/flow.png)
#
# - 70% tidying up the data
# - 30% doing the fun stuff of visualising and presenting
#
# #### Over the coming modules
# - Get the data
# - Analyse it
# - Visulise it
# - Tell stories with it
